# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohanaZuthi/Machine_Learning_Algorithm_Udemy/blob/main/Hierarchical_K_Mean_Clustering_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Impoting Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## **Importing the dataset**

# %%
dataset=pd.read_csv('Mall_Customers.csv')
# in clustering we will take every feature for identifying any patterns
x=dataset.iloc[:,[3,4]].values

# %% [markdown]
# ## **Using the dendrogram to find the optimal number of clusters**

# %% [markdown]
# Variance is a statistical measure that represents the spread or dispersion of a set of values. It tells you how much the individual data points in a dataset differ from the mean (average) of the dataset. The greater the variance, the more spread out the values are from the mean. The smaller the variance, the closer the values are to the mean.

# %% [markdown]
# to lessen the variance method ward is used

# %%
import scipy.cluster.hierarchy as sch
dendrogram=sch.dendrogram(sch.linkage(x,method='ward'))
plt.title('Dendrograms')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# ## **Training the Hierarchical model on the dataset**

# %%
from sklearn.cluster import AgglomerativeClustering
hc=AgglomerativeClustering(n_clusters=5,linkage='ward')
y_hc=hc.fit_predict(x)

# %% [markdown]
# Fit: The fit part of the method means it computes the clustering by:
#
# Finding cluster centers (centroids).
# Iteratively optimizing the assignment of data points to clusters based on their distances to the centroids.
# Predict: The predict part means it assigns each data point in X to one of the computed clusters. The result is a 1D array of cluster labels where each label indicates the cluster number for the corresponding data point in X.

# %% [markdown]
# ## **Visualizing the Clusters**

# %%
# here  y_kmeans==0 means we just want to take the cluster number 0
# and other 0 means we will take all the values of first column which is annual income
plt.scatter(x[y_hc==0,0],x[y_hc==0,1],s=100,c='red',label='cluster 1')
# s is the size of the points for ddisplay
plt.scatter(x[y_hc==1,0],x[y_hc==1,1],s=100,c='blue',label='cluster 2')
plt.scatter(x[y_hc==2,0],x[y_hc==2,1],s=100,c='green',label='cluster 3')
plt.scatter(x[y_hc==3,0],x[y_hc==3,1],s=100,c='cyan',label='cluster 4')
plt.scatter(x[y_hc==4,0],x[y_hc==4,1],s=100,c='black',label='cluster 5')
# 0 crrespondace to x axis

plt.title('cluster of Customers')
plt.xlabel('Annual Income')
plt.ylabel('Spending score (1-100)')
plt.legend()
plt.show()
